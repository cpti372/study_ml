# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
path='/Users/kimyeonsu/Desktop/nct.jpeg'
Image_pil=Image.open(path)
Image=np.array(Image_pil)

# %%
Image.shape
# Out:
# (225, 225, 3)

# %%
np.min(Image)
# Out:
# 0

# %%
np.max(Image)
# Out:
# 255

# %%
plt.hist(Image.ravel(),256,[0,256])
# Out:
# (array([ 758.,   96.,  128.,  116.,  124.,  136.,  170.,  157.,  193.,
#          218.,  227.,  274.,  258.,  291.,  322.,  336.,  340.,  389.,
#          402.,  375.,  421.,  488.,  545.,  532.,  590.,  598.,  616.,
#          578.,  597.,  643.,  604.,  651.,  664.,  655.,  626.,  635.,
#          584.,  547.,  586.,  549.,  536.,  491.,  488.,  513.,  490.,
#          481.,  468.,  437.,  430.,  485.,  490.,  502.,  454.,  477.,
#          467.,  467.,  446.,  441.,  473.,  479.,  424.,  429.,  456.,
#          461.,  456.,  415.,  384.,  412.,  426.,  401.,  380.,  363.,
#          384.,  412.,  414.,  381.,  409.,  413.,  381.,  377.,  398.,
#          381.,  382.,  384.,  389.,  362.,  395.,  397.,  365.,  393.,
#          371.,  360.,  368.,  338.,  352.,  342.,  336.,  348.,  337.,
#          349.,  351.,  374.,  362.,  396.,  387.,  345.,  358.,  356.,
#          357.,  379.,  337.,  334.,  391.,  411.,  435.,  407.,  434.,
# ...

# %%
plt.imshow(Image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-7fde699b3320> in <module>
# ----> 1 plt.imshow(Image)
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
Image_pil.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7FFCF889EB50>

# %%
image_bw=np.array(Image_pil)
plt.figure(figsize=(10,10))
plt.imshow(image_bw,'jet')
plt.colorbar()

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
path2='/Users/kimyeonsu/Desktop/d.jpeg'
Image_pil2=Image.open(path2)
Image2=np.array(Image_pil2)

# %%
Image2.shape
# Out:
# (224, 225, 3)

# %%
import cv2

# %%
Image2_d= cv2.resize(Image2,(225,225))
Image2_d.shape
# Out:
# (225, 225, 3)

# %%
path='/Users/kimyeonsu/Desktop/nct.jpeg'
Image_pil=Image.open(path)
Image=np.arIray(Image_pil)
plt.imshow(Image)

# %%
plt.imshow(Image)

# %%
plt.imshow(Image)
plt.imshow(Image2_d)

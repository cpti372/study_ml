# %% [markdown]
# <a href="https://colab.research.google.com/github/cpti372/study_ml/blob/master/numpy%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.array([1.0,2.0,3.0])
print(x)
# Out:
# [1. 2. 3.]

# %%
x=np.array([1.0,2.0,3.0])
y=np.array([2.0,4.0,6.0])
x+y
# Out:
# array([3., 6., 9.])

# %%
x-y
# Out:
# array([-1., -2., -3.])

# %%
x/y
# Out:
# array([0.5, 0.5, 0.5])

# %%
A=np.array([[1,2],[3,4]])     
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
B=np.array([[3,0],[6,0]])
A+B
A*B
# Out:
# array([[ 3,  0],
#        [18,  0]])

# %%
A=np.array([[1,2],[3,4]])
B=np.array([10,20])
A*B
# Out:
# array([[10, 40],
#        [30, 80]])

# %%
x=np.array([[1,2],[3,4],[5,6]])
print(x)
x[0]
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# array([1, 2])

# %%
for row in x:
  print(row)
# Out:
# [1 2]
# [3 4]
# [5 6]

# %% [markdown]
# x를 1차원 배열로 변환 평탄화

# %%
x=x.flatten()

# %%
print(x)
# Out:
# [1 2 3 4 5 6]

# %%
x[np.array([0,2,4])]
# Out:
# array([1, 3, 5])

# %%
x>2
# Out:
# array([False, False,  True,  True,  True,  True])

# %%
x[x>3]
# Out:
# array([4, 5, 6])

# %%
x[x>2]
# Out:
# array([3, 4, 5, 6])

# %%
import matplotlib.pyplot as plt
x=np.arange(0,6,0.1)

# %%
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1,label="sin")
plt.plot(x,y2,linestyle="--",label="cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos')
plt.legend()
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from google.colab import files
uploaded = files.upload()
img=imread('r.jpg')
plt.imshow(img)
plt.show()
# Out:
#      <input type="file" id="files-a0d402c2-a742-466c-be79-77c326e09222" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0d402c2-a742-466c-be79-77c326e09222">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving r.jpg to r.jpg
